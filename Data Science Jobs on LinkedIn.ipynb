# %%
# Importing relevant libraries
from bs4 import BeautifulSoup
import requests
import openpyxl

# %%
# I bring in the excel component
excel = openpyxl.Workbook()
sheet = excel.active
sheet.title = 'Data Science Jobs on LinkedIn'
sheet.append(['job title', 'company', 'location', 'job url'])

# %%
# Introduced the URL of interest for parsing
source = requests.get('https://www.linkedin.com/jobs/search/?keywords=data%20scientist')
soup = BeautifulSoup(source.text, 'html.parser')

# %%
#Trying to get the right attributes for each category from the html output
jobs_on_linkedin = soup.find('ul', class_='jobs-search__results-list').find_all('li')
print(jobs_on_linkedin)
# Out:
# [<li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3023648528" data-row="1" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="JdUxnbmTGZs2rNLP61TV+g==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-multiple-openings-remote-at-starbucks-3023648528?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=JdUxnbmTGZs2rNLP61TV%2Bg%3D%3D&amp;position=1&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         data scientist (multiple openings) - Remote
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C4D0BAQEQxk9y2rk7Hw/company-logo_100_100/0/1519856020155?e=2147483647&amp;v=beta&amp;t=_oC9h2U0o5a06pSl8JtpB6OsDIQOCzn70V9o5Ikl-p0" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         data scientist (multiple openings) - Remote
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/starbucks?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Starbucks
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Seattle, WA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     2 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3021288840" data-row="2" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="3GhAqQKQjT36pOtA1cx8tg==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/fintech-data-scientist-at-vanguard-3021288840?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=3GhAqQKQjT36pOtA1cx8tg%3D%3D&amp;position=2&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Fintech Data Scientist
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C4D0BAQGlBCOzS6Gl9g/company-logo_100_100/0/1635426862951?e=2147483647&amp;v=beta&amp;t=uisAVERHxI4b6cstdR_9eVNLunIekkTONuBL5dz-_aU" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Fintech Data Scientist
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/vanguard?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Vanguard
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Malvern, PA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate" datetime="2022-04-12">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 days ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3017451601" data-row="3" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="Ae53RdBZVQoVrnEZNqD4ng==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-supply-chain-remote-at-starbucks-3017451601?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=Ae53RdBZVQoVrnEZNqD4ng%3D%3D&amp;position=3&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         data scientist, Supply Chain - Remote
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C4D0BAQEQxk9y2rk7Hw/company-logo_100_100/0/1519856020155?e=2147483647&amp;v=beta&amp;t=_oC9h2U0o5a06pSl8JtpB6OsDIQOCzn70V9o5Ikl-p0" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         data scientist, Supply Chain - Remote
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/starbucks?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Starbucks
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Seattle, WA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/1pwj7aot6lxrfhr9sdta6cnxw" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Actively Hiring
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate" datetime="2022-04-13">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     3 days ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3016834256" data-row="4" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="PUVNeyLfytW/1Fe/cPwKFQ==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-coop-at-comcast-3016834256?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=PUVNeyLfytW%2F1Fe%2FcPwKFQ%3D%3D&amp;position=4&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist Coop
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQGT4d_JDjXclg/company-logo_100_100/0/1561493940923?e=2147483647&amp;v=beta&amp;t=z5nbTaaXvNFOHZx8sEbZzIHPStZf0s-TuncgIJxcr-A" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist Coop
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/comcast?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Comcast
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Philadelphia, PA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/1pwj7aot6lxrfhr9sdta6cnxw" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Actively Hiring
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate" datetime="2022-04-09">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     1 week ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3023633050" data-row="5" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="hQW+cvs+aIGyz5xWibP6DA==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-insights-at-asana-3023633050?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=hQW%2Bcvs%2BaIGyz5xWibP6DA%3D%3D&amp;position=5&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scient
data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/amazon?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Amazon
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Seattle, WA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     10 minutes ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3031111706" data-row="19" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="RblyB1PJBicrq+db7LrPPw==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031111706?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=RblyB1PJBicrq%2Bdb7LrPPw%3D%3D&amp;position=19&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist at Sleep Startup
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQF4mf8zGiwr7Q/company-logo_100_100/0/1553826029580?e=2147483647&amp;v=beta&amp;t=8vdRAdMSwl5LKVKcDLbxefQ679eBxVwbhvrfjJ-WQiM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# ...
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3031116152" data-row="20" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="dRtqLV0giMJtSysw7FAj4A==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031116152?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=dRtqLV0giMJtSysw7FAj4A%3D%3D&amp;position=20&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist at Sleep Startup
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQF4mf8zGiwr7Q/company-logo_100_100/0/1553826029580?e=2147483647&amp;v=beta&amp;t=8vdRAdMSwl5LKVKcDLbxefQ679eBxVwbhvrfjJ-WQiM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist at Sleep Startup
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/recruiting-from-scratch?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Recruiting from Scratch
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Austin, TX
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3031116183" data-row="21" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="TIyfrl/ZkZDWHRgvf4eQiw==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031116183?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=TIyfrl%2FZkZDWHRgvf4eQiw%3D%3D&amp;position=21&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist at Sleep Startup
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQF4mf8zGiwr7Q/company-logo_100_100/0/1553826029580?e=2147483647&amp;v=beta&amp;t=8vdRAdMSwl5LKVKcDLbxefQ679eBxVwbhvrfjJ-WQiM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist at Sleep Startup
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/recruiting-from-scratch?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Recruiting from Scratch
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Menlo Park, CA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3031116186" data-row="22" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="wqTDBR1GcmZZyYqWc1tt1A==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031116186?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=wqTDBR1GcmZZyYqWc1tt1A%3D%3D&amp;position=22&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist at Sleep Startup
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQF4mf8zGiwr7Q/company-logo_100_100/0/1553826029580?e=2147483647&amp;v=beta&amp;t=8vdRAdMSwl5LKVKcDLbxefQ679eBxVwbhvrfjJ-WQiM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist at Sleep Startup
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/recruiting-from-scratch?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Recruiting from Scratch
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Brisbane, CA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3031111733" data-row="23" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="0GcGmLD4/RLJ5DQiCk/UIg==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031111733?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=0GcGmLD4%2FRLJ5DQiCk%2FUIg%3D%3D&amp;position=23&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist at Sleep Startup
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQF4mf8zGiwr7Q/company-logo_100_100/0/1553826029580?e=2147483647&amp;v=beta&amp;t=8vdRAdMSwl5LKVKcDLbxefQ679eBxVwbhvrfjJ-WQiM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist at Sleep Startup
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/recruiting-from-scratch?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Recruiting from Scratch
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             San Carlos, CA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3031113634" data-row="24" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="zhhwIaqHcnE/CfuApqb4VA==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031113634?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=zhhwIaqHcnE%2FCfuApqb4VA%3D%3D&amp;position=24&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist at Sleep Startup
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQF4mf8zGiwr7Q/company-logo_100_100/0/1553826029580?e=2147483647&amp;v=beta&amp;t=8vdRAdMSwl5LKVKcDLbxefQ679eBxVwbhvrfjJ-WQiM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist at Sleep Startup
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/recruiting-from-scratch?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Recruiting from Scratch
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Redwood City, CA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3031111736" data-row="25" data-search-id="gXBZkiot5k1jIyRA3x/KPA==" data-tracking-id="db3UpescrYzLhD55ziXvOg==">
# <a class="base-card__full-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031111736?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&amp;trackingId=db3UpescrYzLhD55ziXvOg%3D%3D&amp;position=25&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="screen-reader-text">
#
#
#         Data Scientist at Sleep Startup
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQF4mf8zGiwr7Q/company-logo_100_100/0/1553826029580?e=2147483647&amp;v=beta&amp;t=8vdRAdMSwl5LKVKcDLbxefQ679eBxVwbhvrfjJ-WQiM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Data Scientist at Sleep Startup
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/recruiting-from-scratch?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Recruiting from Scratch
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Burlingame, CA
#           </span>
# <!-- -->
# <div class="job-search-card__benefits">
# <div class="result-benefits">
# <icon class="result-benefits__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/ee2elqv6ktdjhlrxiyhac6py6" data-svg-class-name="result-benefits__icon-svg"></icon>
# <span class="result-benefits__text">
#          Be an early applicant
# <!-- --> </span>
# </div>
# </div>
# <!-- -->
# <time class="job-search-card__listdate--new" datetime="2022-04-16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>]

# %%
#I will now print the jobs
for job in jobs:
    job_name = job.find('div', 'base-card base-card--link base-search-card base-search-card--link job-search-card').span.get_text(strip=True)
    company_name = job.find('div', 'base-card base-card--link base-search-card base-search-card--link job-search-card').h4.get_text(strip=True)
    location_ = job.find('span', 'job-search-card__location').get_text(strip=True)
    link = job.find('a', 'base-card__full-link')['href']

# %%
#Print would display the output I am looking for
print(job_name)
print(company_name)
print(location_)
print(link)
# Out:
# Data Scientist at Sleep Startup
# Recruiting from Scratch
# Burlingame, CA
# https://www.linkedin.com/jobs/view/data-scientist-at-sleep-startup-at-recruiting-from-scratch-3031111736?refId=gXBZkiot5k1jIyRA3x%2FKPA%3D%3D&trackingId=db3UpescrYzLhD55ziXvOg%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card

# %%
# I intend wrapping it up a;; in an excvel document
sheet.append([job_name, company_name, location_, link])
excel.save('Data Science Jobs on LinkedIn.xlsx')
print(excel.save)
excel.close()
# Out:
# <bound method Workbook.save of <openpyxl.workbook.workbook.Workbook object at 0x0000015127B26C70>>
